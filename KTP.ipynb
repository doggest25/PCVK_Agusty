# %% [markdown]
# <a href="https://colab.research.google.com/github/doggest25/PCVK_Agusty/blob/main/KTP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow  # for image display
from skimage import io
from skimage import transform
from PIL import Image  # Correct import for PIL
import matplotlib.pylab as plt

urls = [
    "https://html.scribdassets.com/7ajitsw43kb94p80/images/1-24e0af29f6.jpg",

]
# Loop through each URL and process the image
for url in urls:
    # Read the image from the URL
    image = io.imread(url)

    # Resize the image
    image= cv.resize(image, (0, 0), fx=0.5, fy=0.5)

    # Convert the image to RGB format
    image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

    # Concatenate the original and processed images side by side
    final_frame = cv.hconcat([image, image_2])

    # Display the final concatenated image
    cv2_imshow(final_frame)
    print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=904x302>

# %%
# Convert image from BGR to RGB
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Dapatkan dimensi gambar
tinggi, lebar, _ = image_rgb.shape

# Tentukan posisi dan ukuran kotak
x_start = 10  # Posisi x awal kotak
y_start = 55  # Posisi y awal kotak
kotak_lebar = 320  # Lebar kotak
kotak_tinggi = 30 # Tinggi kotak

# Tentukan batas kotak
x_end = x_start + kotak_lebar
y_end = y_start + kotak_tinggi

# Tentukan posisi dan ukuran kotak
x2_start = 40  # Posisi x awal kotak
y2_start = 80  # Posisi y awal kotak
kotak_lebar2 = 320  # Lebar kotak
kotak_tinggi2 = 30 # Tinggi kotak

# Tentukan batas kotak
x2_end = x2_start + kotak_lebar2
y2_end = y2_start + kotak_tinggi2

# Gambar kotak putih di gambar

image_rgb[y_start:y_end, x_start:x_end] = [255, 0, 0]  # Warna putih (RGB)

image_rgb[y2_start:y2_end, x2_start:x2_end] = [255, 255, 0]

# Menggabungkan kedua gambar secara horizontal
final_frame = cv.hconcat([image_2, image_rgb])

# Menampilkan gambar hasil
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=904x302>
